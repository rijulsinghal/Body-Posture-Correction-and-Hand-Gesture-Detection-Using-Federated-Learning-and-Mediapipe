# %%
# %pip install mediapipe
# %pip install cv2
# Out:
# Requirement already satisfied: mediapipe in c:\python310\lib\site-packages (0.8.10.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: absl-py in c:\python310\lib\site-packages (from mediapipe) (1.2.0)
# Requirement already satisfied: protobuf<4,>=3.11 in c:\python310\lib\site-packages (from mediapipe) (3.19.1)
# Requirement already satisfied: matplotlib in c:\python310\lib\site-packages (from mediapipe) (3.5.3)
# Requirement already satisfied: opencv-contrib-python in c:\python310\lib\site-packages (from mediapipe) (4.6.0.66)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\hp\appdata\roaming\python\python310\site-packages (from mediapipe) (22.1.0)
# Requirement already satisfied: numpy in c:\python310\lib\site-packages (from mediapipe) (1.23.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\python310\lib\site-packages (from matplotlib->mediapipe) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\python310\lib\site-packages (from matplotlib->mediapipe) (9.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\python310\lib\site-packages (from matplotlib->mediapipe) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\python310\lib\site-packages (from matplotlib->mediapipe) (3.0.6)
# Requirement already satisfied: cycler>=0.10 in c:\python310\lib\site-packages (from matplotlib->mediapipe) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python310\lib\site-packages (from matplotlib->mediapipe) (4.36.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\appdata\roaming\python\python310\site-packages (from matplotlib->mediapipe) (21.3)
# Requirement already satisfied: six>=1.5 in c:\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)
# WARNING: Ignoring invalid distribution -p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python310\lib\site-packages)
#
# [notice] A new release of pip available: 22.2.1 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python310\lib\site-packages)
# ERROR: Could not find a version that satisfies the requirement cv2 (from versions: none)
# ERROR: No matching distribution found for cv2
# WARNING: Ignoring invalid distribution -p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python310\lib\site-packages)
#
# [notice] A new release of pip available: 22.2.1 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Importing Libraries

# %%
import numpy as np
import mediapipe as mp
import glob
import cv2

# %% [markdown]
# Using Media-Pipe Pose for extracting landmarks

# %%
# mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose

# %% [markdown]
# Working on MediaPipe framework and using MediaPipe Pose to extract the landmarks points

# %%
from logging import exception
import re


def medpipe(frame):
    ## Setup mediapipe instance
    #  A confidence score threshold is chosen to filter out false positives and ensure
    #  that a predicted bounding box has a certain minimum score

    with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
        image = cv2.imread(frame,0)
        height, width = image.shape[:2] #getting the shape of the image.
        # Recolor image to RGB
        #cv2.cvtColor() method is used to convert an image from one color space to another.
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False

        # Make detection and handle error conditions if any
        results = pose.process(image)
        if results.pose_landmarks is None:
            return []
        landmarks = results.pose_landmarks.landmark
        return landmarks

# %% [markdown]
# Loading Images from Dataset

# %%
def loadimages(path):
    images = []
    for img in glob.glob(path):
        images.append(img)
    return images

# %% [markdown]
# Extracting Landmarks

# %%
from asyncio.windows_events import NULL
from logging import exception


def getlandmarks(images,label):
    landmarks_matrix = []
    for img in images:
        landmarks = medpipe(img)
        if(len(landmarks) == 0):
            continue
        temp1 = []
        for i in range(0,len(landmarks)):
            temp = []
            temp.append([landmarks[i].x,landmarks[i].y,landmarks[i].z,landmarks[i].visibility])
            temp1.append(temp)
        landmarks_matrix.append([temp1,label])  

    return landmarks_matrix

# %%
images = loadimages('Dataset/Yoga-Dataset/DATASET/TRAIN/downdog/*')
images1 = loadimages('Dataset/Yoga-Dataset/DATASET/TRAIN/goddess/*')
images2 = loadimages('Dataset/Yoga-Dataset/DATASET/TRAIN/plank/*')
images3 = loadimages('Dataset/Yoga-Dataset/DATASET/TRAIN/tree/*')
images4 = loadimages('Dataset/Yoga-Dataset/DATASET/TRAIN/warrior2/*')

# %%
train_matrix = []
train_matrix.append(getlandmarks(images,0))
train_matrix.append(getlandmarks(images1,1))
train_matrix.append(getlandmarks(images2,2))
train_matrix.append(getlandmarks(images3,3))
train_matrix.append(getlandmarks(images4,4))

# %%
print(train_matrix)
# Out:
# [[[[[[0.4431958794593811, 0.6925179362297058, -0.14510515332221985, 0.9979475140571594]], [[0.419335275888443, 0.6950914263725281, -0.1895817071199417, 0.9986032843589783]], [[0.417263388633728, 0.6917432546615601, -0.18957851827144623, 0.9988487958908081]], [[0.41488587856292725, 0.6882607936859131, -0.18967734277248383, 0.9987155199050903]], [[0.41851508617401123, 0.6948370337486267, -0.12462802976369858, 0.9984328150749207]], [[0.41610997915267944, 0.6914787888526917, -0.12447351962327957, 0.9985417127609253]], [[0.4134225845336914, 0.6881003975868225, -0.12432414293289185, 0.9980123043060303]], [[0.4015531837940216, 0.6469379663467407, -0.3166782557964325, 0.9984235763549805]], [[0.39890632033348083, 0.6492432951927185, -0.015786390751600266, 0.9976893663406372]], [[0.4500064551830292, 0.6599215865135193, -0.18380214273929596, 0.9966973066329956]], [[0.4509574770927429, 0.6597610712051392, -0.09656591713428497, 0.9944782257080078]], [[0.42438530921936035, 0.5479850769042969, -0.3911873996257782, 0.9981034994125366]], [[0.42071521282196045, 0.5293667912483215, 0.08496549725532532, 0.9907280206680298]], [[0.3059654235839844, 0.7149161696434021, -0.6544322371482849, 0.9822853803634644]], [[0.2960391342639923, 0.6810068488121033, 0.13893426954746246, 0.23783349990844727]], [[0.16074031591415405, 0.841596782207489, -0.6705203652381897, 0.9581253528594971]], [[0.1694088876247406, 0.7973645925521851, -0.10178951919078827, 0.3565332293510437]], [[0.12219348549842834, 0.8478476405143738, -0.7503129839897156, 0.9411998987197876]], [[0.12473171949386597, 0.8119028806686401, -0.12370485812425613, 0.4760171175003052]], [[0.11404657363891602, 0.8458606004714966, -0.7136273980140686, 0.9344205260276794]], [[0.11742928624153137, 0.819061279296875, -0.17026230692863464, 0.4830189347267151]], [[0.12865829467773438, 0.8401228189468384, -0.6608062386512756, 0.9162887334823608]], [[0.13527724146842957, 0.811164379119873, -0.1291697472333908, 0.4819865822792053]], [[0.6285198926925659, 0.1524292528629303, -0.20917867124080658, 0.9954637885093689]], [[0.6133970618247986, 0.1566651463508606, 0.20965826511383057, 0.9913254380226135]], [[0.7674509882926941, 0.44779545068740845, -0.1594143956899643, 0.9564579725265503]], [[0.7572140693664551, 0.44057056307792664, 0.24491997063159943, 0.14905424416065216]], [[0.8856332898139954, 0.7651941776275635, -0.06944103538990021, 0.9674155116081238]], [[0.867891788482666, 0.7483835220336914, 0.398881733417511, 0.2547903060913086]], [[0.9311124682426453, 0.80082768201828, -0.07221997529268265, 0.971671462059021]], [[0.9108303189277649, 0.7943807244300842, 0.40554600954055786, 0.3451748788356781]], [[0.8226946592330933, 0.8453808426856995, -0.24959130585193634, 0.958903968334198]], [[0.8029630184173584, 0.8276663422584534, 0.30117931962013245, 0.35888993740081787]]], 0], [[[[0.3693738579750061, 0.6969606280326843, -0.1226673424243927, 0.9894441962242126]], [[0.3471994400024414, 0.6779876947402954, -0.165875643491745, 0.9922836422920227]], [[0.34660446643829346, 0.6724651455879211, -0.16590672731399536, 0.9936733245849609]], [[0.34621965885162354, 0.6667898893356323, -0.16602090001106262, 0.9931896328926086]], [[0.34732070565223694, 0.6795512437820435, -0.10177876800298691, 0.9913111925125122]], [[0.34650784730911255, 0.6748974919319153, -0.1017603725194931, 0.9923362135887146]], [[0.34573036432266235, 0.6699649095535278, -0.10182426869869232, 0.9911295175552368]], [[0.35039207339286804, 0.621204137802124, -0.2914741635322571, 0.9897376894950867]], [[0.3474087715148926, 0.6227953433990479, 0.0049153659492731094, 0.9922868013381958]], [[0.3823375403881073, 0.6754040718078613, -0.15959221124649048, 0.984613299369812]], [[0.3836323618888855, 0.6778678894042969, -0.07360013574361801, 0.9817327857017517]], [[0.4137120246887207, 0.5699004530906677, -0.38927099108695984, 0.9938914775848389]], [[0.40045303106307983, 0.5389517545700073, 0.15153668820858002, 0.9830172061920166]], [[0.31378936767578125, 0.732549786567688, - ...
